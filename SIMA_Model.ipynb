# %%
# %pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: openpyxl in ./venv/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.13/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in ./venv/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as numpy
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("NOROESTE_CONCATENATED_DATA.csv")
# Out:
# /var/folders/r5/hhw5dxcj40q577zfh05knt3r0000gn/T/ipykernel_74438/1338312126.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("NOROESTE_CONCATENATED_DATA.csv")

# %%
print ("Dimensión del data set:", df.shape)
# Out:
# Dimensión del data set: (137777, 20)

# %%
print("\nTipos de datos:")
df.info()
# Out:
# Tipos de datos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137777 entries, 0 to 137776
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   datetime     137777 non-null  object
#  1   CO           120726 non-null  float64
#  2   NO           123380 non-null  float64
#  3   NO2          119208 non-null  float64
#  4   NOX          121872 non-null  float64
#  5   O3           119082 non-null  float64
#  6   PM10         131106 non-null  float64
#  7   PM25         83158 non-null   float64
#  8   PRS          133404 non-null  float64
#  9   RAINF        134853 non-null  float64
#  10  RH           119308 non-null  float64
#  11  SO2          113703 non-null  float64
#  12  SR           128329 non-null  float64
#  13  TOUT         130074 non-null  float64
#  14  WSR          128043 non-null  float64
#  15  WDR          100707 non-null  float64
#  16  station      137777 non-null  object
#  17  year_range   137777 non-null  object
#  18  source_file  137777 non-null  object
#  19  WDV          26878 non-null   float64
# dtypes: float64(16), object(4)
# memory usage: 21.0+ MB

# %%
print("\nPrimeras filas:")
display(df.head())
# Out:
# Primeras filas:
#               datetime    CO  NO  NO2  NOX  O3   PM10   PM25    PRS  RAINF  \
# 0  2020-01-01 00:00:00   NaN NaN  NaN  NaN NaN   88.0  70.81    NaN    NaN
# 1  2020-01-01 00:00:00   NaN NaN  NaN  NaN NaN   92.0  86.93    NaN    NaN
# 2  2020-01-01 01:00:00   NaN NaN  NaN  NaN NaN   77.0    NaN  715.0    0.0
# 3  2020-01-01 01:00:00  1.69 NaN  NaN  NaN NaN   54.0    NaN  703.3    0.0
# 4  2020-01-01 02:00:00   NaN NaN  NaN  NaN NaN  107.0  82.65  714.0    0.0
#
#      RH  SO2     SR   TOUT  WSR    WDR    station year_range  \
# 0   NaN  NaN  0.000    NaN  NaN    NaN   NOROESTE  2020-2021
# 1   NaN  NaN  0.000    NaN  NaN    NaN  NOROESTE2  2020-2021
# 2  89.0  NaN  0.002  11.22  5.8    1.0   NOROESTE  2020-2021
# 3  89.0  NaN  0.002  10.19  3.8  138.0  NOROESTE2  2020-2021
# 4  90.0  NaN  0.002  11.03  4.5    NaN   NOROESTE  2020-2021
#
#                                         source_file  WDV
# 0  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx  NaN
# 1  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx  NaN
# 2  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx  NaN
# 3  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx  NaN
# 4  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx  NaN

# %%
print("\nValores nulos por columna:")
nulls = df.isna().sum().sort_values(ascending=False)
display(nulls.to_frame("n_nulos"))
# Out:
# Valores nulos por columna:
#              n_nulos
# WDV           110899
# PM25           54619
# WDR            37070
# SO2            24074
# O3             18695
# NO2            18569
# RH             18469
# CO             17051
# NOX            15905
# NO             14397
# WSR             9734
# SR              9448
# TOUT            7703
# PM10            6671
# PRS             4373
# RAINF           2924
# station            0
# year_range         0
# source_file        0
# datetime           0

# %%
print("\nPorcentaje de nulos por columna:")
display((df.isna().mean()*100).round(2).sort_values(ascending=False).to_frame("%_nulos"))
# Out:
# Porcentaje de nulos por columna:
#              %_nulos
# WDV            80.49
# PM25           39.64
# WDR            26.91
# SO2            17.47
# O3             13.57
# NO2            13.48
# RH             13.40
# CO             12.38
# NOX            11.54
# NO             10.45
# WSR             7.07
# SR              6.86
# TOUT            5.59
# PM10            4.84
# PRS             3.17
# RAINF           2.12
# station         0.00
# year_range      0.00
# source_file     0.00
# datetime        0.00

# %%
display(df.describe())
# Out:
#                   CO             NO            NO2            NOX  \
# count  120726.000000  123380.000000  119208.000000  121872.000000
# mean        1.405502      13.785789      13.229912      26.773679
# std         0.919648      26.836988      30.654026      30.265775
# min         0.050000       0.500000   -9999.000000       0.500000
# 25%         0.660000       3.300000       6.600000      11.800000
# 50%         1.270000       5.400000      10.500000      17.900000
# 75%         1.930000      13.100000      17.600000      31.500000
# max        22.380000     945.100000     103.400000     971.800000
#
#                   O3           PM10          PM25            PRS  \
# count  119082.000000  131106.000000  83158.000000  133404.000000
# mean       26.712874      57.922443     20.282141     709.410395
# std        19.520352      41.657423     16.230040       8.685180
# min         1.000000       2.000000      2.000000     680.000000
# 25%        12.000000      32.000000     10.440000     702.600000
# 50%        22.000000      49.000000     16.730000     709.200000
# 75%        36.400000      72.247500     26.000000     714.300000
# max       162.000000     998.000000    999.000000     740.000000
#
#                RAINF             RH            SO2             SR  \
# count  134853.000000  119308.000000  113703.000000  128329.000000
# mean        0.010368      56.169901       4.808103      -1.242984
# std         0.341736      21.934682       3.581992     118.415726
# min         0.000000       0.000000       0.500000   -9999.000000
# 25%         0.000000      39.000000       2.700000       0.000000
# 50%         0.000000      58.000000       3.600000       0.013000
# 75%         0.000000      74.000000       5.400000       0.277000
# max        37.600000     714.200000     192.100000       2.000000
#
#                 TOUT            WSR            WDR           WDV
# count  130074.000000  128043.000000  100707.000000  26878.000000
# mean       23.086708       9.569903     135.721215    145.127465
# std        40.030159       7.576224      99.247676     92.776801
# min     -9999.000000       0.100000       1.000000      1.000000
# 25%        18.450000       4.900000      68.000000     85.000000
# 50%        23.910000       8.600000     104.000000    106.000000
# 75%        28.390000      12.900000     195.000000    224.750000
# max       785.000000     215.900000     360.000000    360.000000

# %%
obj_cols = df.select_dtypes(exclude="number").columns.tolist()
if obj_cols:
    print("\nEstadísticas descriptivas (categóricas):")
    display(df[obj_cols].describe())
# Out:
# Estadísticas descriptivas (categóricas):
#                    datetime   station year_range  \
# count                137777    137777     137777
# unique                43839         3          5
# top     2024-05-02 07:00:00  NOROESTE  2023-2024
# freq                      6     54446      41610
#
#                                               source_file
# count                                              137777
# unique                                                  4
# top     DATOS HISTÓRICOS 2023_2024_TODAS ESTACIONES_IT...
# freq                                                41610

# %%
for col in df.select_dtypes(exclude="number").columns:
    print(f"\nTop categorías en {col}:")
    display(df[col].value_counts(dropna=False).head(10))
# Out:
# Top categorías en datetime:
# datetime
# 2024-05-02 07:00:00    6
# 2024-03-02 14:00:00    6
# 2024-03-02 22:00:00    6
# 2024-03-02 21:00:00    6
# 2024-03-02 20:00:00    6
# 2024-03-02 19:00:00    6
# 2024-03-02 18:00:00    6
# 2024-03-02 17:00:00    6
# 2024-03-02 16:00:00    6
# 2024-03-02 15:00:00    6
# Name: count, dtype: int64
# Top categorías en station:
# station
# NOROESTE     54446
# NOROESTE2    54442
# NOROESTE3    28889
# Name: count, dtype: int64
# Top categorías en year_range:
# year_range
# 2023-2024    41610
# 2020-2021    35072
# 2022-2023    34747
# 2024         19643
# 2024          6705
# Name: count, dtype: int64
# Top categorías en source_file:
# source_file
# DATOS HISTÓRICOS 2023_2024_TODAS ESTACIONES_ITESM.xlsx    41610
# DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx          35072
# DATOS HISTÓRICOS 2022_2023_TODAS ESTACIONES.xlsx          34747
# DATOS HISTÓRICOS 2024_TODAS ESTACIONES.xlsx               26348
# Name: count, dtype: int64

# %%
dup_count = df.duplicated().sum()
print(f"\nFilas duplicadas: {dup_count}")
# Out:
# Filas duplicadas: 0

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()

# %%
for col in num_cols[:12]: 
    plt.figure()
    plt.hist(df[col].dropna(), bins=30)
    plt.title(f"Histograma: {col}")
    plt.xlabel(col); plt.ylabel("Frecuencia")
    plt.show()

# %%
for col in num_cols[:12]:
    plt.figure()
    plt.boxplot(df[col].dropna(), vert=False)
    plt.title(f"Boxplot: {col}")
    plt.xlabel(col)
    plt.show()

# %%
plt.imshow(df.isna(), aspect='auto', interpolation='nearest')
plt.title("Mapa simple de valores nulos")
plt.xlabel("Columnas"); plt.ylabel("Filas")
plt.colorbar(label="Nulo=1 / No nulo=0")
plt.show()

# %%
df.drop_duplicates(inplace=True)

print("Dimensión final:", df.shape)
# Out:
# Dimensión final: (137777, 20)

# %%
import matplotlib.pyplot as plt

num_cols = df.select_dtypes(include="number").columns

for col in num_cols:
    plt.figure()
    plt.hist(df[col].dropna(), bins=30, edgecolor="k")
    plt.title(f"Distribución de {col}")
    plt.xlabel(col); plt.ylabel("Frecuencia")
    plt.show()

# %%
df_imputado = df.copy()
df_imputado = df_imputado.fillna(df_imputado.mean(numeric_only=True))
df_imputado
# Out:
#                    datetime        CO         NO        NO2        NOX  \
# 0       2020-01-01 00:00:00  1.405502  13.785789  13.229912  26.773679
# 1       2020-01-01 00:00:00  1.405502  13.785789  13.229912  26.773679
# 2       2020-01-01 01:00:00  1.405502  13.785789  13.229912  26.773679
# 3       2020-01-01 01:00:00  1.690000  13.785789  13.229912  26.773679
# 4       2020-01-01 02:00:00  1.405502  13.785789  13.229912  26.773679
# ...                     ...       ...        ...        ...        ...
# 137772  2024-12-31 22:00:00  0.504000   7.900000  20.400000  24.400000
# 137773  2024-12-31 22:00:00  2.220000  13.900000  47.800000  61.700000
# 137774  2024-12-31 23:00:00  3.390000  11.500000  44.700000  56.300000
# 137775  2024-12-31 23:00:00  1.970000  10.300000  37.900000  48.200000
# 137776  2024-12-31 23:00:00  0.588000   8.600000  22.500000  27.200000
#
#                O3    PM10        PM25         PRS     RAINF         RH  \
# 0       26.712874   88.00   70.810000  709.410395  0.010368  56.169901
# 1       26.712874   92.00   86.930000  709.410395  0.010368  56.169901
# 2       26.712874   77.00   20.282141  715.000000  0.000000  89.000000
# 3       26.712874   54.00   20.282141  703.300000  0.000000  89.000000
# 4       26.712874  107.00   82.650000  714.000000  0.000000  90.000000
# ...           ...     ...         ...         ...       ...        ...
# 137772  18.000000   67.00   20.282141  732.000000  0.000000  50.000000
# 137773  12.000000   98.00   20.282141  717.200000  0.000000  28.000000
# 137774  12.000000  503.03  306.820000  721.600000  0.000000  30.000000
# 137775  13.000000  150.00   20.282141  717.800000  0.000000  30.000000
# 137776  14.900000   77.00   20.282141  733.000000  0.000000  53.000000
#
#              SO2        SR       TOUT       WSR         WDR    station  \
# 0       4.808103  0.000000  23.086708  9.569903  135.721215   NOROESTE
# 1       4.808103  0.000000  23.086708  9.569903  135.721215  NOROESTE2
# 2       4.808103  0.002000  11.220000  5.800000    1.000000   NOROESTE
# 3       4.808103  0.002000  10.190000  3.800000  138.000000  NOROESTE2
# 4       4.808103  0.002000  11.030000  4.500000  135.721215   NOROESTE
# ...          ...       ...        ...       ...         ...        ...
# 137772  3.000000 -1.242984  15.300000  1.000000    5.000000  NOROESTE3
# 137773  5.000000  0.000000  20.690000  2.100000  260.000000  NOROESTE2
# 137774  6.200000 -1.242984  23.086708  6.100000   39.000000   NOROESTE
# 137775  4.900000  0.000000  18.720000  3.800000  199.000000  NOROESTE2
# 137776  3.100000 -1.242984  14.100000  1.400000   86.000000  NOROESTE3
#
#        year_range                                       source_file  \
# 0       2020-2021  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx
# 1       2020-2021  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx
# 2       2020-2021  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx
# 3       2020-2021  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx
# 4       2020-2021  DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx
# ...           ...                                               ...
# 137772       2024       DATOS HISTÓRICOS 2024_TODAS ESTACIONES.xlsx
# 137773       2024       DATOS HISTÓRICOS 2024_TODAS ESTACIONES.xlsx
# 137774       2024       DATOS HISTÓRICOS 2024_TODAS ESTACIONES.xlsx
# 137775       2024       DATOS HISTÓRICOS 2024_TODAS ESTACIONES.xlsx
# 137776       2024       DATOS HISTÓRICOS 2024_TODAS ESTACIONES.xlsx
#
#                WDV
# 0       145.127465
# 1       145.127465
# 2       145.127465
# 3       145.127465
# 4       145.127465
# ...            ...
# 137772  145.127465
# 137773  145.127465
# 137774  145.127465
# 137775  145.127465
# 137776  145.127465
#
# [137777 rows x 20 columns]
